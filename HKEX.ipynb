# %% [markdown]
# <a href="https://colab.research.google.com/github/pjs888/Hello-World_2/blob/master/HKEX.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from datetime import datetime
import time
import re
res = requests.get('https://www.hkex.com.hk/Market-Data/Securities-Prices/Equities/Equities-Quote?sym=700&sc_lang=zh-HK')
res.text
#m = re.search('LabCI.getToken = function \(\) { (.+?); };', ' '.join(res.text.split()) )
#token = m.group(1).split('return')[-1].replace('"','').strip()
#dt = int(time.mktime(datetime.now().timetuple()))
#res = requests.get(f'https://www1.hkex.com.hk/hkexwidget/data/getchartdata2?hchart=1&span=0&int=0&ric=2828.HK&token={token}&qid={dt}&callback=jQuery_{dt}')
#res.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n\r\n<html xmlns="http://www.w3.org/1999/xhtml" lang="zh-HK" xml:lang="zh-HK" data-wf-page="5e37e0bcc62330e0912344e8" class="market-hkex" prefix="og: http://ogp.me/ns#">\r\n<head><title>\r\n\t詳細資料\r\n</title><meta charset="utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" /><meta content="width=device-width, initial-scale=1" name="viewport" /><link href="/assets/images/favicon.png" rel="shortcut icon" type="image/x-icon" /><link href="/assets/images/webclip.png" rel="apple-touch-icon" />\r\n\r\n<!-- Seo Meta Tag Component -->\r\n<meta name="keywords" content="股本證券之市場數據" />\r\n<meta name="description" content="此網頁提供在香港交易所市場上市的股本證券之市場數據 (例如: 價格、成交金額、市值、市盈率及收益率等)。" />\r\n<meta name="twitter:card" content="summary_large_image" />\r\n<meta name="twitter:site" content="@hkexgroup" />\r\n<meta name="twitter:title" content="詳細資料" />\r\n<meta name="twitter:description" content="此網頁提供在香港交易所市場上市的股本證券之市場數據 (例如: 價格、成交金額、市值、市盈率及收益率等)。" />\r\n<meta na
# ...

# %%
m2 = re.match('jQuery_\d+\((.+)\)',res.text)

# %%
import json
jd = json.loads(m2.group(1))

# %%
import pandas
df = pandas.DataFrame(jd['data']['datalist'])

# %%
df

# %%
re.search
